# %%
import pandas as pd

# %%
df_approved = pd.read_csv("data/drugbank/structure links.csv")
df_approved.head()
# Out:
#   DrugBank ID          Name   CAS Number                Drug Groups  \
# 0     DB00006   Bivalirudin  128270-60-0  approved; investigational
# 1     DB00007    Leuprolide   53714-56-0  approved; investigational
# 2     DB00014     Goserelin   65807-02-5                   approved
# 3     DB00027  Gramicidin D    1405-97-6                   approved
# 4     DB00035  Desmopressin   16679-58-6                   approved
#
#                       InChIKey  \
# 0  OIRCOABEOLEUMC-GEJPAHFPSA-N
# 1  GFIJNRVAKGFPGQ-LIJARHBVSA-N
# 2  BLCLNMBMMGCOAS-URPVMXJPSA-N
# 3  NDAYQJDHGXTBJL-MWWSRJDJSA-N
# 4  NFLWUMRGJYTJIN-PNIOQBSNSA-N
#
#                                                InChI  \
# 0  InChI=1S/C98H138N24O33/c1-5-52(4)82(96(153)122...
# 1  InChI=1S/C59H84N16O12/c1-6-63-57(86)48-14-10-2...
# 2  InChI=1S/C59H84N18O14/c1-31(2)22-40(49(82)68-3...
# 3  InChI=1S/C96H135N19O16/c1-50(2)36-71(105-79(11...
# 4  InChI=1S/C46H64N14O12S2/c47-35(62)15-14-29-40(...
#
# ...

# %%
df_drug_link = pd.read_csv("data/drugbank/drug links.csv")
df_drug_link.head()
# Out:
#   DrugBank ID                 Name   CAS Number    Drug Type KEGG Compound ID  \
# 0     DB00001            Lepirudin  138068-37-8  BiotechDrug              NaN
# 1     DB00002            Cetuximab  205923-56-4  BiotechDrug              NaN
# 2     DB00003         Dornase alfa  143831-71-4  BiotechDrug              NaN
# 3     DB00004  Denileukin diftitox  173146-27-5  BiotechDrug              NaN
# 4     DB00005           Etanercept  185243-69-0  BiotechDrug           C07897
#
#   KEGG Drug ID  PubChem Compound ID  PubChem Substance ID  ChEBI ID  \
# 0       D06880                  NaN            46507011.0       NaN
# 1       D03455                  NaN            46507042.0       NaN
# 2          NaN                  NaN            46507792.0       NaN
# 3          NaN                  NaN            46506950.0       NaN
# 4       D00742                  NaN            46506732.0       NaN
#
#    PharmGKB ID  ... GenBank ID DPD ID  \
# 0     PA450195  ...        NaN  11916
# ...

# %%
df_uniport_link = pd.read_csv("data/drugbank/uniprot links.csv")
df_uniport_link.head()
# Out:
#   DrugBank ID          Name               Type UniProt ID  \
# 0     DB00006   Bivalirudin  SmallMoleculeDrug     P05164
# 1     DB00035  Desmopressin  SmallMoleculeDrug     P35354
# 2     DB00035  Desmopressin  SmallMoleculeDrug     P23219
# 3     DB00091  Cyclosporine  SmallMoleculeDrug     P33261
# 4     DB00091  Cyclosporine  SmallMoleculeDrug     P10635
#
#                    UniProt Name
# 0               Myeloperoxidase
# 1  Prostaglandin G/H synthase 2
# 2  Prostaglandin G/H synthase 1
# 3          Cytochrome P450 2C19
# 4           Cytochrome P450 2D6
